# %%
import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
f1 = pd.read_csv('forest_1to13.csv')
f1.head()
# Out:
#             State/UT Geographical Area Very dense forest-2001  \
# 0     Andhra Pradesh          2,75,069                 25,827
# 1  Arunachal Pradesh            83,743                 53,932
# 2              Assam            78,438                 15,830
# 3              Bihar            94,163                  3,372
# 4       Chhattisgarh          1,35,191                 37,880
#
#   Open forest-2001 Total-2001 Very dense forest-2003 Mod. dense forest-2003  \
# 0           18,810     44,637                     23                 24,356
# 1           14,113     68,045                 13,907                 39,604
# 2           11,884     27,714                  1,684                 11,358
# 3            2,348      5,720                     76                  2,951
# 4           18,568     56,448                  1,540                 37,440
#
#   Open forest-2003 Total-2003 Very dense forest-2005  ... Open forest-2007  \
# ...

# %%
f2 = pd.read_csv('forest_15to19.csv')
f2.head()
# Out:
#             State/UT Geographical Area Very dense forest-2015  \
# 0     Andhra Pradesh          1,60,204                    375
# 1  Arunachal Pradesh            83,743                 20,804
# 2              Assam            78,438                  1,441
# 3              Bihar            94,163                    248
# 4       Chhattisgarh          1,35,191                  4,152
#
#   Mod. dense forest-2015 Open forest-2015 Total-2015 Very dense forest-2017  \
# 0                 13,093           10,956     24,424                  1,957
# 1                 31,301           15,143     67,248                 20,721
# 2                 11,268           14,914     27,623                  2,797
# 3                  3,376            3,664      7,288                    332
# 4                 34,846           16,588     55,586                  7,064
#
#   Mod. dense forest-2017 Open forest-2017 Total-2017 Very dense forest-2019  \
# ...

# %%
f3 = pd.DataFrame(f1)
cols = [0, 1]
f3 = f3[f3.columns[cols]]

# %%
f3.rename(columns={'State/UT':'State/UT', 'Geographical Area':'Geographical Area_1-13'}, inplace=True)

# %%
f3.head()
# Out:
#             State/UT Geographical Area_1-13
# 0     Andhra Pradesh               2,75,069
# 1  Arunachal Pradesh                 83,743
# 2              Assam                 78,438
# 3              Bihar                 94,163
# 4       Chhattisgarh               1,35,191

# %%
f4 = pd.DataFrame(f2)
cols = [1]
f4 = f4[f4.columns[cols]]

# %%
f4.rename(columns={'Geographical Area':'Geographical Area_15-19'}, inplace=True)

# %%
f4.head()
# Out:
#   Geographical Area_15-19
# 0                1,60,204
# 1                  83,743
# 2                  78,438
# 3                  94,163
# 4                1,35,191

# %%
f5 = pd.concat([f3, f4], axis=1, sort=False)

# %%
f5.head()
# Out:
#             State/UT Geographical Area_1-13 Geographical Area_15-19
# 0     Andhra Pradesh               2,75,069                1,60,204
# 1  Arunachal Pradesh                 83,743                  83,743
# 2              Assam                 78,438                  78,438
# 3              Bihar                 94,163                  94,163
# 4       Chhattisgarh               1,35,191                1,35,191

# %%
f6 = f1.drop(['State/UT', 'Geographical Area'], axis = 1)
f6.head()
# Out:
#   Very dense forest-2001 Open forest-2001 Total-2001 Very dense forest-2003  \
# 0                 25,827           18,810     44,637                     23
# 1                 53,932           14,113     68,045                 13,907
# 2                 15,830           11,884     27,714                  1,684
# 3                  3,372            2,348      5,720                     76
# 4                 37,880           18,568     56,448                  1,540
#
#   Mod. dense forest-2003 Open forest-2003 Total-2003 Very dense forest-2005  \
# 0                 24,356           20,040     44,419                    130
# 1                 39,604           14,508     68,019                 14,411
# 2                 11,358           14,784     27,826                  1,444
# 3                  2,951            2,531      5,558                    110
# 4                 37,440           17,018     55,998                  2,256
#
# ...

# %%
f7 = pd.concat([f5, f6], axis = 1, sort = False)
f7.head()
# Out:
#             State/UT Geographical Area_1-13 Geographical Area_15-19  \
# 0     Andhra Pradesh               2,75,069                1,60,204
# 1  Arunachal Pradesh                 83,743                  83,743
# 2              Assam                 78,438                  78,438
# 3              Bihar                 94,163                  94,163
# 4       Chhattisgarh               1,35,191                1,35,191
#
#   Very dense forest-2001 Open forest-2001 Total-2001 Very dense forest-2003  \
# 0                 25,827           18,810     44,637                     23
# 1                 53,932           14,113     68,045                 13,907
# 2                 15,830           11,884     27,714                  1,684
# 3                  3,372            2,348      5,720                     76
# 4                 37,880           18,568     56,448                  1,540
#
#   Mod. dense forest-2003 Open forest-2003 Total-2003  ... Open forest-2007  \
# ...

# %%
f8 = f2.drop(['State/UT', 'Geographical Area'], axis = 1)
f8.head()
# Out:
#   Very dense forest-2015 Mod. dense forest-2015 Open forest-2015 Total-2015  \
# 0                    375                 13,093           10,956     24,424
# 1                 20,804                 31,301           15,143     67,248
# 2                  1,441                 11,268           14,914     27,623
# 3                    248                  3,376            3,664      7,288
# 4                  4,152                 34,846           16,588     55,586
#
#   Very dense forest-2017 Mod. dense forest-2017 Open forest-2017 Total-2017  \
# 0                  1,957                 14,051           12,139     28,147
# 1                 20,721                 30,955           15,288     66,964
# 2                  2,797                 10,192           15,116     28,105
# 3                    332                  3,260            3,707      7,299
# 4                  7,064                 32,215           16,268     55,547
#
# ...

# %%
forest_cover = pd.concat([f7, f8], axis = 1, sort = False)
forest_cover.head()
# Out:
#             State/UT Geographical Area_1-13 Geographical Area_15-19  \
# 0     Andhra Pradesh               2,75,069                1,60,204
# 1  Arunachal Pradesh                 83,743                  83,743
# 2              Assam                 78,438                  78,438
# 3              Bihar                 94,163                  94,163
# 4       Chhattisgarh               1,35,191                1,35,191
#
#   Very dense forest-2001 Open forest-2001 Total-2001 Very dense forest-2003  \
# 0                 25,827           18,810     44,637                     23
# 1                 53,932           14,113     68,045                 13,907
# 2                 15,830           11,884     27,714                  1,684
# 3                  3,372            2,348      5,720                     76
# 4                 37,880           18,568     56,448                  1,540
#
#   Mod. dense forest-2003 Open forest-2003 Total-2003  ... Open forest-2015  \
# ...

# %%
forest_cover.to_csv('forest_cover.csv', na_rep='Null', float_format='%.2f', index=False, encoding='utf-8')#area in km2
