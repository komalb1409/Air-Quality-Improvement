# %%
import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup

# %%
f1 = pd.read_csv('forest_1to5.csv')
f1.head()
# Out:
#             State/UT Geographical Area Very dense forest-2001  \
# 0     Andhra Pradesh          2,75,069                 25,827
# 1  Arunachal Pradesh            83,743                 53,932
# 2              Assam            78,438                 15,830
# 3              Bihar            94,163                  3,372
# 4       Chhattisgarh          1,35,191                 37,880
#
#   Open forest-2001 Total-2001 Very dense forest-2003 Mod. dense forest-2003  \
# 0           18,810     44,637                     23                 24,356
# 1           14,113     68,045                 13,907                 39,604
# 2           11,884     27,714                  1,684                 11,358
# 3            2,348      5,720                     76                  2,951
# 4           18,568     56,448                  1,540                 37,440
#
#   Open forest-2003 Total-2003 Very dense forest-2005 Mod. dense forest-2005  \
# ...

# %%
f2 = pd.read_csv('forest_7to13.csv')
f2.head()
# Out:
#             State/UT Geographical Area Very dense forest-2007  \
# 0     Andhra Pradesh          2,75,069                    820
# 1  Arunachal Pradesh            83,743                 20,858
# 2              Assam            78,438                  1,461
# 3              Bihar            94,163                    231
# 4       Chhattisgarh          1,35,191                  4,162
#
#   Mod. dense forest-2007 Open forest-2007 Total-2007 Very dense forest-2011  \
# 0                 24,757           19,525     45,102                     23
# 1                 31,556           14,939     67,353                 13,907
# 2                 11,558           14,673     27,692                  1,684
# 3                  3,248            3,325      6,804                     76
# 4                 35,038           16,670     55,870                  1,540
#
#   Mod. dense forest-2011 Open forest-2011 Total-2011 Very dense forest-2013  \
# ...

# %%
f3 = pd.read_csv('forest_15.csv')
f3.head()
# Out:
#             State/UT Geographical Area Very dense forest-2015  \
# 0     Andhra Pradesh          1,60,204                    375
# 1  Arunachal Pradesh            83,743                 20,804
# 2              Assam            78,438                  1,441
# 3              Bihar            94,163                    248
# 4       Chhattisgarh          1,35,191                  4,152
#
#   Mod. dense forest-2015 Open forest-2015 Total-2015  \
# 0                 13,093           10,956     24,424
# 1                 31,301           15,143     67,248
# 2                 11,268           14,914     27,623
# 3                  3,376            3,664      7,288
# 4                 34,846           16,588     55,586
#
#    Percent of Geographical Area  Scrub
# 0                         15.25  8,562
# 1                         80.30    264
# 2                         35.22    384
# 3                          7.74    120
# 4                         41.12    117

# %%
f4 = pd.read_csv('forest_17.csv')
f4.head()
# Out:
#             State/UT Geographical Area Very dense forest-2017  \
# 0     Andhra Pradesh          1,62,968                  1,957
# 1  Arunachal Pradesh            83,743                 20,721
# 2              Assam            78,438                  2,797
# 3              Bihar            94,163                    332
# 4       Chhattisgarh          1,35,192                  7,064
#
#   Mod. dense forest-2017 Open forest-2017 Total-2017  \
# 0                 14,051           12,139     28,147
# 1                 30,955           15,288     66,964
# 2                 10,192           15,116     28,105
# 3                  3,260            3,707      7,299
# 4                 32,215           16,268     55,547
#
#    Percent of Geographical Area  Scrub
# 0                         17.27  9,560
# 1                         79.96    247
# 2                         35.83    217
# 3                          7.75    228
# 4                         41.09    552

# %%
f5 = pd.read_csv('forest_19.csv')
f5.head()
# Out:
#             State/UT Geographical Area Very dense forest-2019  \
# 0     Andhra Pradesh          1,62,968                  1,994
# 1  Arunachal Pradesh            83,743                 21,095
# 2              Assam            78,438                  2,795
# 3              Bihar            94,163                    333
# 4       Chhattisgarh          1,35,192                  7,068
#
#   Mod. dense forest-2019 Open forest-2019 Total-2019  \
# 0                 13,938           13,205     29,137
# 1                 30,557           15,036     66,688
# 2                 10,279           15,253     28,327
# 3                  3,280            3,693      7,306
# 4                 32,198           16,345     55,611
#
#    Percent of Geographical Area  Scrub
# 0                         17.88  8,255
# 1                         79.63    229
# 2                         36.11    173
# 3                          7.76    250
# 4                         41.13    610

# %%
df1 = f2.drop(['State/UT', 'Geographical Area'], axis = 1)
df1.head()
# Out:
#   Very dense forest-2007 Mod. dense forest-2007 Open forest-2007 Total-2007  \
# 0                    820                 24,757           19,525     45,102
# 1                 20,858                 31,556           14,939     67,353
# 2                  1,461                 11,558           14,673     27,692
# 3                    231                  3,248            3,325      6,804
# 4                  4,162                 35,038           16,670     55,870
#
#   Very dense forest-2011 Mod. dense forest-2011 Open forest-2011 Total-2011  \
# 0                     23                 24,356           20,040     44,419
# 1                 13,907                 39,604           14,508     68,019
# 2                  1,684                 11,358           14,784     27,826
# 3                     76                  2,951            2,531      5,558
# 4                  1,540                 37,440           17,018     55,998
#
# ...

# %%
forest1 = pd.concat([f1, df1], axis=1, sort=False)

# %%
print(forest1)
# Out:
#                 State/UT Geographical Area Very dense forest-2001  \
# 0         Andhra Pradesh          2,75,069                 25,827
# 1      Arunachal Pradesh            83,743                 53,932
# 2                  Assam            78,438                 15,830
# 3                  Bihar            94,163                  3,372
# 4           Chhattisgarh          1,35,191                 37,880
# 5                  Delhi             1,483                     38
# 6                    Goa             3,702                  1,785
# 7                Gujarat          1,96,022                  8,673
# 8                Haryana            44,212                  1,139
# 9       Himachal Pradesh            55,673                 10,429
# 10       Jammu & Kashmir          2,22,236                 11,848
# 11             Jharkhand            79,714                 11,787
# 12             Karnataka          1,91,791                 26,156
# ...

# %%
forest1.head()
# Out:
#             State/UT Geographical Area Very dense forest-2001  \
# 0     Andhra Pradesh          2,75,069                 25,827
# 1  Arunachal Pradesh            83,743                 53,932
# 2              Assam            78,438                 15,830
# 3              Bihar            94,163                  3,372
# 4       Chhattisgarh          1,35,191                 37,880
#
#   Open forest-2001 Total-2001 Very dense forest-2003 Mod. dense forest-2003  \
# 0           18,810     44,637                     23                 24,356
# 1           14,113     68,045                 13,907                 39,604
# 2           11,884     27,714                  1,684                 11,358
# 3            2,348      5,720                     76                  2,951
# 4           18,568     56,448                  1,540                 37,440
#
#   Open forest-2003 Total-2003 Very dense forest-2005  ... Open forest-2007  \
# ...

# %%
forest1.to_csv('forest_1to13.csv', na_rep='Null', float_format='%.2f', index=False, encoding='utf-8')#area in km2

# %%
df2 = f3.drop(['Percent of Geographical Area', 'Scrub'], axis = 1)
df2.head()
# Out:
#             State/UT Geographical Area Very dense forest-2015  \
# 0     Andhra Pradesh          1,60,204                    375
# 1  Arunachal Pradesh            83,743                 20,804
# 2              Assam            78,438                  1,441
# 3              Bihar            94,163                    248
# 4       Chhattisgarh          1,35,191                  4,152
#
#   Mod. dense forest-2015 Open forest-2015 Total-2015
# 0                 13,093           10,956     24,424
# 1                 31,301           15,143     67,248
# 2                 11,268           14,914     27,623
# 3                  3,376            3,664      7,288
# 4                 34,846           16,588     55,586

# %%
df3 = f4.drop(['State/UT', 'Geographical Area', 'Percent of Geographical Area', 'Scrub'], axis = 1)
df3.head()
# Out:
#   Very dense forest-2017 Mod. dense forest-2017 Open forest-2017 Total-2017
# 0                  1,957                 14,051           12,139     28,147
# 1                 20,721                 30,955           15,288     66,964
# 2                  2,797                 10,192           15,116     28,105
# 3                    332                  3,260            3,707      7,299
# 4                  7,064                 32,215           16,268     55,547

# %%
df4 = f5.drop(['State/UT', 'Geographical Area', 'Percent of Geographical Area', 'Scrub'], axis = 1)
df4.head()
# Out:
#   Very dense forest-2019 Mod. dense forest-2019 Open forest-2019 Total-2019
# 0                  1,994                 13,938           13,205     29,137
# 1                 21,095                 30,557           15,036     66,688
# 2                  2,795                 10,279           15,253     28,327
# 3                    333                  3,280            3,693      7,306
# 4                  7,068                 32,198           16,345     55,611

# %%
r = pd.concat([df2, df3], axis=1, sort=False)

# %%
forest2 = pd.concat([r, df4], axis=1, sort=False)

# %%
print(forest2)
# Out:
#                 State/UT Geographical Area Very dense forest-2015  \
# 0         Andhra Pradesh          1,60,204                    375
# 1      Arunachal Pradesh            83,743                 20,804
# 2                  Assam            78,438                  1,441
# 3                  Bihar            94,163                    248
# 4           Chhattisgarh          1,35,191                  4,152
# 5                  Delhi             1,483                   6.94
# 6                    Goa             3,702                    542
# 7                Gujarat          1,96,022                    376
# 8                Haryana            44,212                     27
# 9       Himachal Pradesh            55,673                  3,224
# 10      Jammu & Kashmir*          2,22,236                  4,061
# 11             Jharkhand            79,714                  2,588
# 12             Karnataka          1,91,791                  1,781
# ...

# %%
forest2.to_csv('forest_15to19.csv', na_rep='Null', float_format='%.2f', index=False, encoding='utf-8')#area in km2
