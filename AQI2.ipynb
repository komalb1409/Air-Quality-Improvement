# %%
import pandas as pd
import numpy as np

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.plotly as py
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 7)

# %%
dataset = pd.read_csv('india-air-quality-data2.csv', engine = 'python' , encoding = 'unicode_escape')

# %%
print(dataset)
# Out:
#        stn_code   sampling_date           state   location  \
# 0           150  June - M061990  Andhra Pradesh  Hyderabad
# 1           151  June - M061990  Andhra Pradesh  Hyderabad
# 2           152  June - M061990  Andhra Pradesh  Hyderabad
# 3           150  July - M071990  Andhra Pradesh  Hyderabad
# 4           152  July - M071990  Andhra Pradesh  Hyderabad
# ...         ...             ...             ...        ...
# 380401     SAMP      12-12-2015     West Bengal   ULUBERIA
# 380402     SAMP      15-12-2015     West Bengal   ULUBERIA
# 380403     SAMP      18-12-2015     West Bengal   ULUBERIA
# 380404     SAMP      21-12-2015     West Bengal   ULUBERIA
# 380405     SAMP      24-12-2015     West Bengal   ULUBERIA
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# ...

# %%
print(dataset['AQI'])
# Out:
# 0          89.000
# 1          62.750
# 2          83.750
# 3          74.125
# 4          87.000
#            ...
# 380320    154.000
# 380321    141.750
# 380322    148.750
# 380323    161.500
# 380324    168.000
# Name: AQI, Length: 380325, dtype: float64

# %%
dataset['AQI'] = dataset.AQI.astype(float)

# %%
dataset.dtypes
# Out:
# stn_code                        object
# sampling_date                   object
# state                           object
# location                        object
# agency                          object
# type                            object
# so2                            float64
# no2                            float64
# rspm                           float64
# spm                            float64
# location_monitoring_station     object
# pm2_5                          float64
# date                            object
# formula                        float64
# AQI                            float64
# dtype: object

# %%
dataset[['AQI','state']].groupby(['state']).median()
# Out:
#                            AQI
# state
# Andhra Pradesh         84.7500
# Arunachal Pradesh      48.2500
# Assam                  70.2500
# Bihar                 185.9375
# Chandigarh             80.5000
# Chhattisgarh          136.5000
# Dadra & Nagar Haveli  101.4375
# Daman & Diu            82.2500
# Delhi                 227.6250
# Goa                    42.8500
# Gujarat               121.1250
# Haryana               153.8350
# Himachal Pradesh       67.5000
# Jammu & Kashmir        82.7500
# Jharkhand             181.5000
# Karnataka              86.6250
# Kerala                 50.5000
# Madhya Pradesh        116.5000
# Maharashtra           118.1450
# Manipur                84.7500
# Meghalaya              39.0000
# Mizoram                30.7500
# Nagaland               55.2500
# Odisha                 81.7500
# Puducherry             54.1875
# Punjab                140.5000
# Rajasthan             156.8750
# Tamil Nadu             79.6250
# Telangana              74.7500
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
pf=pd.read_csv("india-air-quality-data2.csv", encoding= 'unicode_escape')
pf=pf.fillna(0)

pf['date'] = pd.to_datetime(pf['date'])
pf=pf.fillna(0)
af=pf[pf['location']=='Delhi'].loc[(pf['date'].dt.year>=2000)].groupby(pf.date.dt.year)['AQI'].agg('mean')

plt.figure(figsize=(15,8))

plt.plot(af,'b')


plt.xlabel('Years')
plt.ylabel('Mean AQI')
plt.title('aqi')

blue_patch = mpatches.Patch(color='blue', label='delhi')

plt.legend(handles=[blue_patch])

plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(af)
# Out:
# date
# 2000    256.382143
# 2001    247.265464
# 2002    227.684783
# 2003    249.661809
# 2005    251.888657
# 2006    276.040596
# 2007    265.081023
# 2008    306.491252
# 2009    320.110720
# 2011    190.919209
# 2012    229.809896
# 2013    231.881919
# 2014    194.871159
# 2015    200.564295
# Name: AQI, dtype: float64

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
pf['date'] = pd.to_datetime(pf['date'])
plt.figure(figsize=(15,8))

list1=['Delhi','Pune','Ahmedabad','Kolkata','Chennai','Hyderabad','Mumbai']
for i in list1:
    mask=(pf['date'].dt.year>=2000)&(pf['date'].dt.year>=2004)
    af=pf[pf['location']==i].loc[mask].groupby(pf.date.dt.year)['AQI'].agg('mean')
    plt.plot(af,label=i)
    plt.legend()
    
plt.xlabel('Years')
plt.ylabel('Mean AQI of each year')
plt.title('AQI LEVEL OF ALL METROPOLITAN CITIES')
plt.show()

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
pf['date'] = pd.to_datetime(pf['date'])
plt.figure(figsize=(12,8))

list1=['Delhi','Pune','Ahmedabad','Kolkata','Chennai','Hyderabad','Mumbai']
for i in list1:
    mask=(pf['date'].dt.year>=2000)&(pf['date'].dt.year<=2004)
    af=pf[pf['location']==i].loc[mask].groupby(pf.date.dt.year)['AQI'].agg('mean')
    plt.plot(af,label=i)
    plt.legend()
    
plt.xlabel('Years')
plt.ylabel('Mean AQI of each year')
plt.title('AQI LEVEL OF ALL METROPOLITAN CITIES')
plt.show()

# %%
y=dataset[['AQI','state']].groupby(['state']).median()

# %%
print(y)
# Out:
#                            AQI
# state
# Andhra Pradesh         84.7500
# Arunachal Pradesh      48.2500
# Assam                  70.2500
# Bihar                 185.9375
# Chandigarh             80.5000
# Chhattisgarh          136.5000
# Dadra & Nagar Haveli  101.4375
# Daman & Diu            82.2500
# Delhi                 227.6250
# Goa                    42.8500
# Gujarat               121.1250
# Haryana               153.8350
# Himachal Pradesh       67.5000
# Jammu & Kashmir        82.7500
# Jharkhand             181.5000
# Karnataka              86.6250
# Kerala                 50.5000
# Madhya Pradesh        116.5000
# Maharashtra           118.1450
# Manipur                84.7500
# Meghalaya              39.0000
# Mizoram                30.7500
# Nagaland               55.2500
# Odisha                 81.7500
# Puducherry             54.1875
# Punjab                140.5000
# Rajasthan             156.8750
# Tamil Nadu             79.6250
# Telangana              74.7500
# ...

# %%
x=dataset['state'].unique()
print(x)
# Out:
# ['Andhra Pradesh' 'Haryana' 'Arunachal Pradesh' 'Goa' 'Chandigarh'
#  'Daman & Diu' 'Dadra & Nagar Haveli' 'Delhi' 'Assam' 'Gujarat' 'Bihar'
#  'Chhattisgarh' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand'
#  'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya'
#  'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab' 'Rajasthan'
#  'Tamil Nadu' 'Telangana' 'Uttar Pradesh' 'Uttarakhand' 'Uttaranchal'
#  'West Bengal']

# %%
pf['date'] = pd.to_datetime(pf['date'])
plt.figure(figsize=(12,8))


for i in x:
    mask=(pf['date'].dt.year>=2000)&(pf['date'].dt.year<=2004)
    af=pf[pf['state']==i].loc[mask].groupby(pf.date.dt.year)['AQI'].agg('mean')
    plt.plot(af,label=i)
    plt.legend()

# %%
d=dataset.groupby('state')

# %%
P=d['AQI'].mean()

# %%
print(P)
# Out:
# state
# Andhra Pradesh          100.498718
# Arunachal Pradesh        50.222222
# Assam                    82.201752
# Bihar                   198.026559
# Chandigarh               93.019229
# Chhattisgarh            138.939942
# Dadra & Nagar Haveli    105.251128
# Daman & Diu              93.319070
# Delhi                   248.158306
# Goa                      51.663473
# Gujarat                 130.193581
# Haryana                 155.822052
# Himachal Pradesh         84.449781
# Jammu & Kashmir          82.925444
# Jharkhand               189.296648
# Karnataka               101.668380
# Kerala                   55.202480
# Madhya Pradesh          130.302694
# Maharashtra             133.602884
# Manipur                  84.169118
# Meghalaya                59.147937
# Mizoram                  34.649722
# Nagaland                 60.808280
# Odisha                   91.918028
# Puducherry               69.918680
# Punjab                  141.977622
# ...

# %%
mask1=(pf['date'].dt.year>=2000)&(pf['date'].dt.year<=2004)
mask2=(pf['date'].dt.year>=2005)&(pf['date'].dt.year<=2009)
mask3=(pf['date'].dt.year>=2010)&(pf['date'].dt.year<=2014)
mask4=(pf['date'].dt.year>=2013)&(pf['date'].dt.year<=2015)
af1=pf[pf['state']=='Delhi'].loc[mask1]['AQI'].agg('mean')
af2=pf[pf['state']=='Delhi'].loc[mask2]['AQI'].agg('mean')
af3=pf[pf['state']=='Delhi'].loc[mask3]['AQI'].agg('mean')
af4=pf[pf['state']=='Delhi'].loc[mask4]['AQI'].agg('mean')
bf1=pf[pf['state']=='Haryana'].loc[mask1]['AQI'].agg('mean')
bf2=pf[pf['state']=='Haryana'].loc[mask2]['AQI'].agg('mean')
bf3=pf[pf['state']=='Haryana'].loc[mask3]['AQI'].agg('mean')
bf4=pf[pf['state']=='Haryana'].loc[mask4]['AQI'].agg('mean')
cf1=pf[pf['state']=='Maharashtra'].loc[mask1]['AQI'].agg('mean')
cf2=pf[pf['state']=='Maharashtra'].loc[mask2]['AQI'].agg('mean')
cf3=pf[pf['state']=='Maharashtra'].loc[mask3]['AQI'].agg('mean')
cf4=pf[pf['state']=='Maharashtra'].loc[mask4]['AQI'].agg('mean')
df1=pf[pf['state']=='Kerala'].loc[mask1]['AQI'].agg('mean')
df2=pf[pf['state']=='Kerala'].loc[mask2]['AQI'].agg('mean')
df3=pf[pf['state']=='Kerala'].loc[mask3]['AQI'].agg('mean')
df4=pf[pf['state']=='Kerala'].loc[mask4]['AQI'].agg('mean')
ef1=pf[pf['state']=='Gujarat'].loc[mask1]['AQI'].agg('mean')
ef2=pf[pf['state']=='Gujarat'].loc[mask2]['AQI'].agg('mean')
ef3=pf[pf['state']=='Gujarat'].loc[mask3]['AQI'].agg('mean')
ef4=pf[pf['state']=='Gujarat'].loc[mask4]['AQI'].agg('mean')
ff1=pf[pf['state']=='Uttar Pradesh'].loc[mask1]['AQI'].agg('mean')
ff2=pf[pf['state']=='Uttar Pradesh'].loc[mask2]['AQI'].agg('mean')
ff3=pf[pf['state']=='Uttar Pradesh'].loc[mask3]['AQI'].agg('mean')
ff4=pf[pf['state']=='Uttar Pradesh'].loc[mask4]['AQI'].agg('mean')
gf1=pf[pf['state']=='West Bengal'].loc[mask1]['AQI'].agg('mean')
gf2=pf[pf['state']=='West Bengal'].loc[mask2]['AQI'].agg('mean')
gf3=pf[pf['state']=='West Bengal'].loc[mask3]['AQI'].agg('mean')
gf4=pf[pf['state']=='West Bengal'].loc[mask4]['AQI'].agg('mean')
hf1=pf[pf['state']=='Tamil Nadu'].loc[mask1]['AQI'].agg('mean')
hf2=pf[pf['state']=='Tamil Nadu'].loc[mask2]['AQI'].agg('mean')
hf3=pf[pf['state']=='Tamil Nadu'].loc[mask3]['AQI'].agg('mean')
hf4=pf[pf['state']=='Tamil Nadu'].loc[mask4]['AQI'].agg('mean')

# %%
hf4=pf[pf['state']=='Tamil Nadu'].loc[pf['date'].dt.year>=2013]['AQI'].agg('mean')

# %%
import numpy as np
import matplotlib.pyplot as plt
n_groups = 4

range = (af1,af2,af3,af4)
range1 =(bf1,bf2,bf3,bf4)


fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.22
opacity = 0.5

rects1 = plt.bar(index,range,bar_width,
alpha=opacity,
color='b',
label='Delhi')

 
rects2 = plt.bar(index + bar_width, range1, bar_width,
alpha=opacity,
color='r',
label='Haryana')
plt.xlabel('year')
plt.ylabel('AQI')
plt.title('comparsion')
plt.xticks(index , ('2004','2008','2012','2015'))
plt.legend()
plt.show()

# %%
df = pd.read_csv('forest_1to13.csv', engine = 'python' , encoding = 'unicode_escape')
print(df)
# Out:
#                 State/UT Geographical Area Very dense forest-2001  \
# 0         Andhra Pradesh          2,75,069                 25,827
# 1      Arunachal Pradesh            83,743                 53,932
# 2                  Assam            78,438                 15,830
# 3                  Bihar            94,163                  3,372
# 4           Chhattisgarh          1,35,191                 37,880
# 5                  Delhi             1,483                     38
# 6                    Goa             3,702                  1,785
# 7                Gujarat          1,96,022                  8,673
# 8                Haryana            44,212                  1,139
# 9       Himachal Pradesh            55,673                 10,429
# 10       Jammu & Kashmir          2,22,236                 11,848
# 11             Jharkhand            79,714                 11,787
# 12             Karnataka          1,91,791                 26,156
# ...

# %%
d1=df.loc[df['State/UT'] == 'Delhi','mean2004'].iloc[0]
d2=df.loc[df['State/UT'] == 'Delhi','mean2009'].iloc[0]
d3=df.loc[df['State/UT'] == 'Delhi','mean2014'].iloc[0]
h1=df.loc[df['State/UT'] == 'Haryana','mean2004'].iloc[0]
h2=df.loc[df['State/UT'] == 'Haryana','mean2009'].iloc[0]
h3=df.loc[df['State/UT'] == 'Haryana','mean2014'].iloc[0]
m1=df.loc[df['State/UT'] == 'Maharashtra','mean2004'].iloc[0]
m2=df.loc[df['State/UT'] == 'Maharashtra','mean2009'].iloc[0]
m3=df.loc[df['State/UT'] == 'Maharashtra','mean2014'].iloc[0]
k1=df.loc[df['State/UT'] == 'Kerala','mean2004'].iloc[0]
k2=df.loc[df['State/UT'] == 'Kerala','mean2009'].iloc[0]
k3=df.loc[df['State/UT'] == 'Kerala','mean2014'].iloc[0]
g1=df.loc[df['State/UT'] == 'Gujarat','mean2004'].iloc[0]
g2=df.loc[df['State/UT'] == 'Gujarat','mean2009'].iloc[0]
g3=df.loc[df['State/UT'] == 'Gujarat','mean2014'].iloc[0]
u1=df.loc[df['State/UT'] == 'Uttar Pradesh','mean2004'].iloc[0]
u2=df.loc[df['State/UT'] == 'Uttar Pradesh','mean2009'].iloc[0]
u3=df.loc[df['State/UT'] == 'Uttar Pradesh','mean2014'].iloc[0]
w1=df.loc[df['State/UT'] == 'West Bengal','mean2004'].iloc[0]
w2=df.loc[df['State/UT'] == 'West Bengal','mean2009'].iloc[0]
w3=df.loc[df['State/UT'] == 'West Bengal','mean2014'].iloc[0]
t1=df.loc[df['State/UT'] == 'Tamil Nadu','mean2004'].iloc[0]
t2=df.loc[df['State/UT'] == 'Tamil Nadu','mean2009'].iloc[0]
t3=df.loc[df['State/UT'] == 'Tamil Nadu','mean2014'].iloc[0]

# %%
import numpy as np
import matplotlib.pyplot as plt
n_groups = 8

range = (af1,bf1,cf1,df1,ef1,ff1,gf1,hf1)

r=(d1,h1,m1,k1,g1,u1,w1,t1)

fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.22
opacity = 0.5

rects1 = plt.bar(index, range, bar_width,
alpha=opacity,
color='b')


plt.xlabel('state')
plt.ylabel('AQI')
plt.title('AQI mean between yeear 2000-2004')
plt.xticks(index , ('Delhi','Haryana','Maharastra','Kerala','Gujarat','UttarPradesh','West Bengal','Tamil Nadu'),rotation=90)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt
n_groups = 8

range = (af2,bf2,cf2,df2,ef2,ff2,gf2,hf2)



fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.22
opacity = 0.5

rects1 = plt.bar(index,range,bar_width,
alpha=opacity)

 

plt.xlabel('state')
plt.ylabel('AQI')
plt.title('AQI mean between yeear 2005-2009')
plt.xticks(index , ('Delhi','Haryana','Maharastra','Kerala','Gujarat','UttarPradesh','West Bengal','Tamil Nadu'),rotation=90)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt
n_groups = 8

range = (af3,bf3,cf3,df3,ef3,ff3,gf3,hf3)



fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.22
opacity = 0.5

rects1 = plt.bar(index,range,bar_width,
alpha=opacity)

 

plt.xlabel('state')
plt.ylabel('AQI')
plt.title('AQI mean between yeear 2010-2014')
plt.xticks(index , ('Delhi','Haryana','Maharastra','Kerala','Gujarat','UttarPradesh','West Bengal','Tamil Nadu'),rotation=90)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
print(r[1])
# Out:
# 1635.5

# %%
df5 = pd.read_csv('forest_15to19.csv', engine = 'python' , encoding = 'unicode_escape')
print(df5)
# Out:
#                 State/UT Geographical Area Very dense forest-2015  \
# 0         Andhra Pradesh          1,60,204                    375
# 1      Arunachal Pradesh            83,743                 20,804
# 2                  Assam            78,438                  1,441
# 3                  Bihar            94,163                    248
# 4           Chhattisgarh          1,35,191                  4,152
# 5                  Delhi             1,483                   6.94
# 6                    Goa             3,702                    542
# 7                Gujarat          1,96,022                    376
# 8                Haryana            44,212                     27
# 9       Himachal Pradesh            55,673                  3,224
# 10      Jammu & Kashmir*          2,22,236                  4,061
# 11             Jharkhand            79,714                  2,588
# 12             Karnataka          1,91,791                  1,781
# ...

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
a=df.loc[df['State/UT'] == 'Delhi','Total-2001'].iloc[0]
b=df.loc[df['State/UT'] == 'Delhi','Total-2003'].iloc[0]
c=df.loc[df['State/UT'] == 'Delhi','Total-2005'].iloc[0]
d=df.loc[df['State/UT'] == 'Delhi','Total-2007'].iloc[0]
e=df.loc[df['State/UT'] == 'Delhi','Total-2011'].iloc[0]
f=df.loc[df['State/UT'] == 'Delhi','Total-2013'].iloc[0]
a1=df.loc[df['State/UT'] == 'Haryana','Total-2001'].iloc[0]
b1=df.loc[df['State/UT'] == 'Haryana','Total-2003'].iloc[0]
c1=df.loc[df['State/UT'] == 'Haryana','Total-2005'].iloc[0]
d1=df.loc[df['State/UT'] == 'Haryana','Total-2007'].iloc[0]
e1=df.loc[df['State/UT'] == 'Haryana','Total-2011'].iloc[0]
f1=df.loc[df['State/UT'] == 'Haryana','Total-2013'].iloc[0]
a2=df.loc[df['State/UT'] == 'Maharashtra','Total-2001'].iloc[0]
b2=df.loc[df['State/UT'] == 'Maharashtra','Total-2003'].iloc[0]
c2=df.loc[df['State/UT'] == 'Maharashtra','Total-2005'].iloc[0]
d2=df.loc[df['State/UT'] == 'Maharashtra','Total-2007'].iloc[0]
e2=df.loc[df['State/UT'] == 'Maharashtra','Total-2011'].iloc[0]
f2=df.loc[df['State/UT'] == 'Maharashtra','Total-2013'].iloc[0]
a3=df.loc[df['State/UT'] == 'Kerala','Total-2001'].iloc[0]
b3=df.loc[df['State/UT'] == 'Kerala','Total-2003'].iloc[0]
c3=df.loc[df['State/UT'] == 'Kerala','Total-2005'].iloc[0]
d3=df.loc[df['State/UT'] == 'Kerala','Total-2007'].iloc[0]
e3=df.loc[df['State/UT'] == 'Kerala','Total-2011'].iloc[0]
f3=df.loc[df['State/UT'] == 'Kerala','Total-2013'].iloc[0]
a4=df.loc[df['State/UT'] == 'Gujarat','Total-2001'].iloc[0]
b4=df.loc[df['State/UT'] == 'Gujarat','Total-2003'].iloc[0]
c4=df.loc[df['State/UT'] == 'Gujarat','Total-2005'].iloc[0]
d4=df.loc[df['State/UT'] == 'Gujarat','Total-2007'].iloc[0]
e4=df.loc[df['State/UT'] == 'Gujarat','Total-2011'].iloc[0]
f4=df.loc[df['State/UT'] == 'Gujarat','Total-2013'].iloc[0]
a5=df.loc[df['State/UT'] == 'Uttar Pradesh','Total-2001'].iloc[0]
b5=df.loc[df['State/UT'] == 'Uttar Pradesh','Total-2003'].iloc[0]
c5=df.loc[df['State/UT'] == 'Uttar Pradesh','Total-2005'].iloc[0]
d5=df.loc[df['State/UT'] == 'Uttar Pradesh','Total-2007'].iloc[0]
e5=df.loc[df['State/UT'] == 'Uttar Pradesh','Total-2011'].iloc[0]
f5=df.loc[df['State/UT'] == 'Uttar Pradesh','Total-2013'].iloc[0]
a6=df.loc[df['State/UT'] == 'West Bengal','Total-2001'].iloc[0]
b6=df.loc[df['State/UT'] == 'West Bengal','Total-2003'].iloc[0]
c6=df.loc[df['State/UT'] == 'West Bengal','Total-2005'].iloc[0]
d6=df.loc[df['State/UT'] == 'West Bengal','Total-2007'].iloc[0]
e6=df.loc[df['State/UT'] == 'West Bengal','Total-2011'].iloc[0]
f6=df.loc[df['State/UT'] == 'West Bengal','Total-2013'].iloc[0]
a7=df.loc[df['State/UT'] == 'Tamil Nadu','Total-2001'].iloc[0]
b7=df.loc[df['State/UT'] == 'Tamil Nadu','Total-2003'].iloc[0]
c7=df.loc[df['State/UT'] == 'Tamil Nadu','Total-2005'].iloc[0]
d7=df.loc[df['State/UT'] == 'Tamil Nadu','Total-2007'].iloc[0]
e7=df.loc[df['State/UT'] == 'Tamil Nadu','Total-2011'].iloc[0]
f7=df.loc[df['State/UT'] == 'Tamil Nadu','Total-2013'].iloc[0]
g=df5.loc[df5['State/UT'] == 'Delhi','Total-2015'].iloc[0]
h=df5.loc[df5['State/UT'] == 'Delhi','Total-2017'].iloc[0]
i=df5.loc[df5['State/UT'] == 'Delhi','Total-2019'].iloc[0]
g1=df5.loc[df5['State/UT'] == 'Haryana','Total-2015'].iloc[0]
h1=df5.loc[df5['State/UT'] == 'Haryana','Total-2017'].iloc[0]
i1=df5.loc[df5['State/UT'] == 'Haryana','Total-2019'].iloc[0]
g2=df5.loc[df5['State/UT'] == 'Maharashtra','Total-2015'].iloc[0]
h2=df5.loc[df5['State/UT'] == 'Maharashtra','Total-2017'].iloc[0]
i2=df5.loc[df5['State/UT'] == 'Maharashtra','Total-2019'].iloc[0]
g3=df5.loc[df5['State/UT'] == 'Kerala','Total-2015'].iloc[0]
h3=df5.loc[df5['State/UT'] == 'Kerala','Total-2017'].iloc[0]
i3=df5.loc[df5['State/UT'] == 'Kerala','Total-2019'].iloc[0]
g4=df5.loc[df5['State/UT'] == 'Gujarat','Total-2015'].iloc[0]
h4=df5.loc[df5['State/UT'] == 'Gujarat','Total-2017'].iloc[0]
i4=df5.loc[df5['State/UT'] == 'Gujarat','Total-2019'].iloc[0]
g5=df5.loc[df5['State/UT'] == 'Uttar Pradesh','Total-2015'].iloc[0]
h5=df5.loc[df5['State/UT'] == 'Uttar Pradesh','Total-2017'].iloc[0]
i5=df5.loc[df5['State/UT'] == 'Uttar Pradesh','Total-2019'].iloc[0]
g6=df5.loc[df5['State/UT'] == 'West Bengal','Total-2015'].iloc[0]
h6=df5.loc[df5['State/UT'] == 'West Bengal','Total-2017'].iloc[0]
i6=df5.loc[df5['State/UT'] == 'West Bengal','Total-2019'].iloc[0]
g7=df5.loc[df5['State/UT'] == 'Tamil Nadu','Total-2015'].iloc[0]
h7=df5.loc[df5['State/UT'] == 'Tamil Nadu','Total-2017'].iloc[0]
i7=df5.loc[df5['State/UT'] == 'Tamil Nadu','Total-2019'].iloc[0]
year=[2001,2003,2005,2007,2011,2013,2015,2017,2019]
fo=[a,b,c,d,e,f,g,h,i]
fo1=[a1,b1,c1,d1,e1,f1,g1,h1,i1]
fo2=[a2,b2,c2,d2,e2,f2,g2,h2,i2]
fo3=[a3,b3,c3,d3,e3,f3,g3,h3,i3]
fo4=[a4,b4,c4,d4,e4,f4,g4,h4,i4]
fo5=[a5,b5,c5,d5,e5,f5,g5,h5,i5]
fo6=[a6,b6,c6,d6,e6,f6,g6,h6,i6]
fo7=[a7,b7,c7,d7,e7,f7,g7,h7,i7]
plt.plot(year,fo,label='delhi')
plt.plot(year,fo1,label='haryana')
plt.plot(year,fo2,label='Maharastra')
plt.plot(year,fo3,label='kerala')
plt.plot(year,fo4,label='gujrat')
plt.plot(year,fo5,label='uttar pradesh')
plt.plot(year,fo6,label='west bengal')
plt.plot(year,fo7,label='tamil nadu')

plt.legend()


plt.xlabel('Years')
plt.ylabel('forest cover')
plt.title('state forest cover ')
plt.show()
